# %%
from scipy.io import wavfile
import IPython
import numpy as np
import matplotlib.pyplot as plt

fs, data = wavfile.read('res/train_set/dcase2016_task2_train/clearthroat002.wav')
IPython.display.Audio(data, rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from scipy.io import wavfile
import IPython
import numpy as np


fs, data = wavfile.read('res/train_set/dcase2016_task2_train/speech002.wav')
IPython.display.Audio(data, rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import os

directory = "res/train_set/dcase2016_task2_train/"

examples = []

for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename.endswith(".wav"): 
        wav_name = os.path.join(directory, filename)
        fs, data = wavfile.read(wav_name)

        assert fs == 44100

        examples.append(data)

# %%
length_examples = map(len, examples)

# %%
plt.hist(list(length_examples))
# Out:
# (array([28., 44., 49., 23., 29., 17., 15.,  5.,  4.,  6.]),
#  array([  5601. ,  19748.3,  33895.6,  48042.9,  62190.2,  76337.5,
#          90484.8, 104632.1, 118779.4, 132926.7, 147074. ]),
#  <BarContainer object of 10 artists>)

# %%
fs
# Out:
# 44100

# %%
directory
# Out:
# b'res/train_set/dcase2016_task2_train/'

# %%
filename
# Out:
# 'clearthroat002.wav'
